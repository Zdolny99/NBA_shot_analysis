# %%
import json
import pandas
import requests
import nba_api

from nba_api.stats.endpoints import shotchartdetail

# %%
response = shotchartdetail.ShotChartDetail(
	team_id=0,
	player_id=201935,
	season_nullable='2018-19',
	season_type_all_star='Regular Season'
)

content = json.loads(response.get_json())

# %%
import requests
import json

url_base = 'https://stats.nba.com/stats/shotchartdetail'

headers = {
		'Host': 'stats.nba.com',
		'Connection': 'keep-alive',
		'Accept': 'application/json, text/plain, */*',
		'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
		'Referer': 'https://stats.nba.com/',
		"x-nba-stats-origin": "stats",
		"x-nba-stats-token": "true",
		'Accept-Encoding': 'gzip, deflate, br',
		'Accept-Language': 'en-US,en;q=0.9',
	}

parameters = {
	'ContextMeasure': 'FGA',
	'LastNGames': 0,
	'LeagueID': '00',
	'Month': 0,
	'OpponentTeamID': 0,
	'Period': 0,
	'PlayerID': 201935,
	'SeasonType': 'Regular Season',
	'TeamID': 0,
	'VsDivision': '',
	'VsConference': '',
	'SeasonSegment': '',
	'Season': '2018-19',
	'RookieYear': '',
	'PlayerPosition': '',
	'Outcome': '',
	'Location': '',
	'GameSegment': '',
	'GameId': '',
	'DateTo': '',
	'DateFrom': ''
}


response = requests.get(url_base, params=parameters, headers=headers)
content = json.loads(response.content)

# %%
import pandas as pd

# transform contents into dataframe
results = content['resultSets'][0]
headers = results['headers']
rows = results['rowSet']
df = pd.DataFrame(rows)
df.columns = headers

# write to csv file
df.to_csv('content.csv', index=False)

# %%
print(df)
# print(content[content.keys()[0]])
# Out:
#               GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID   PLAYER_NAME  \
# 0     Shot Chart Detail  0021800009             11     201935  James Harden
# 1     Shot Chart Detail  0021800009             28     201935  James Harden
# 2     Shot Chart Detail  0021800009             55     201935  James Harden
# 3     Shot Chart Detail  0021800009            103     201935  James Harden
# 4     Shot Chart Detail  0021800009            246     201935  James Harden
# ...                 ...         ...            ...        ...           ...
# 1904  Shot Chart Detail  0021801218            452     201935  James Harden
# 1905  Shot Chart Detail  0021801218            565     201935  James Harden
# 1906  Shot Chart Detail  0021801218            596     201935  James Harden
# 1907  Shot Chart Detail  0021801218            615     201935  James Harden
# 1908  Shot Chart Detail  0021801218            656     201935  James Harden
#
#          TEAM_ID        TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0     1610612745  Houston Rockets       1                 11
# 1     1610612745  Houston Rockets       1                  9
# 2     1610612745  Houston Rockets       1                  7
# 3     1610612745  Houston Rockets       1                  4
# 4     1610612745  Houston Rockets       2                  6
# ...          ...              ...     ...                ...
# 1904  1610612745  Houston Rockets       3                  2
# 1905  1610612745  Houston Rockets       4                  5
# 1906  1610612745  Houston Rockets       4                  3
# 1907  1610612745  Houston Rockets       4                  1
# 1908  1610612745  Houston Rockets       4                  0
#
#       SECONDS_REMAINING  ...         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0                    17  ...              Center(C)  Less Than 8 ft.
# 1                    33  ...              Center(C)          24+ ft.
# 2                    51  ...              Center(C)          24+ ft.
# 3                    12  ...   Left Side Center(LC)          24+ ft.
# 4                     6  ...              Center(C)  Less Than 8 ft.
# ...                 ...  ...                    ...              ...
# 1904                 41  ...  Right Side Center(RC)          24+ ft.
# 1905                 36  ...              Center(C)  Less Than 8 ft.
# 1906                  5  ...              Center(C)  Less Than 8 ft.
# 1907                 54  ...              Center(C)          24+ ft.
# 1908                  0  ...              Center(C)          24+ ft.
#
#      SHOT_DISTANCE LOC_X LOC_Y SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  \
# 0                1     3    12                   1               0   20181017
# 1               27   -61   264                   1               0   20181017
# 2               25    -1   259                   1               0   20181017
# 3               26  -120   232                   1               1   20181017
# 4                2     3    20                   1               1   20181017
# ...            ...   ...   ...                 ...             ...        ...
# 1904            25    90   243                   1               1   20190409
# 1905             5     8    57                   1               0   20190409
# 1906             1   -14     1                   1               0   20190409
# 1907            27     3   276                   1               0   20190409
# 1908            24    32   241                   1               0   20190409
#
#       HTM  VTM
# 0     HOU  NOP
# 1     HOU  NOP
# 2     HOU  NOP
# 3     HOU  NOP
# 4     HOU  NOP
# ...   ...  ...
# 1904  OKC  HOU
# 1905  OKC  HOU
# 1906  OKC  HOU
# 1907  OKC  HOU
# 1908  OKC  HOU
#
# [1909 rows x 24 columns]
